# %%
print("Hello Qgene")
# Out:
# Hello Qgene

# %%
# Cell 1: Test basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("✅ Basic libraries work!")

# Cell 2: Test ML libraries
from sklearn.ensemble import RandomForestClassifier
import shap
print("✅ ML libraries work!")

# Cell 3: Test Qiskit (quantum)
import qiskit
print("✅ Qiskit works!")
print(f"Qiskit version: {qiskit.__version__}")

# Cell 4: Test Flask
import flask
print("✅ Flask works!")

print("\n🎉 All libraries installed successfully!")
# Out:
# ✅ Basic libraries work!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Cell 2: Test ML libraries
#       8 from sklearn.ensemble import RandomForestClassifier
# ----> 9 import shap
#      10 print("✅ ML libraries work!")
#      12 # Cell 3: Test Qiskit (quantum)
#
# ModuleNotFoundError: No module named 'shap'

# %%
# Test everything again
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import shap
import qiskit
import flask

print("✅ Basic libraries work!")
print("✅ ML libraries work!")
print("✅ SHAP works!")
print("✅ Qiskit works!")
print(f"Qiskit version: {qiskit.__version__}")
print("✅ Flask works!")
print("\n🎉 All libraries installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.ensemble import RandomForestClassifier
# ----> 6 import shap
#       7 import qiskit
#       8 import flask
#
# ModuleNotFoundError: No module named 'shap'

# %%
# Test everything again with SHAP included
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import shap
import qiskit
import flask

print("✅ Basic libraries work!")
print("✅ ML libraries work!")
print("✅ SHAP works!")
print(f"   SHAP version: {shap.__version__}")
print("✅ Qiskit works!")
print(f"   Qiskit version: {qiskit.__version__}")
print("✅ Flask works!")
print("\n🎉 All libraries installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.ensemble import RandomForestClassifier
# ----> 6 import shap
#       7 import qiskit
#       8 import flask
#
# ModuleNotFoundError: No module named 'shap'

# %%
# Check if shap is actually installed
import sys
print(f"Python location: {sys.executable}")
print(f"Python version: {sys.version}")

# Try to find shap
try:
    import shap
    print(f"✅ SHAP found! Version: {shap.__version__}")
except ImportError as e:
    print(f"❌ SHAP not found: {e}")
# Out:
# Python location: c:\Users\anany\anaconda3\python.exe
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# ❌ SHAP not found: No module named 'shap'

# %%
# Final test
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import shap
import qiskit
import flask

print("✅ Basic libraries work!")
print("✅ ML libraries work!")
print("✅ SHAP works!")
print(f"   SHAP version: {shap.__version__}")
print("✅ Qiskit works!")
print(f"   Qiskit version: {qiskit.__version__}")
print("✅ Flask works!")
print("\n🎉 All libraries installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 from sklearn.ensemble import RandomForestClassifier
#       6 import shap
# ----> 7 import qiskit
#       8 import flask
#      10 print("✅ Basic libraries work!")
#
# ModuleNotFoundError: No module named 'qiskit'

# %%
# Final test
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import shap
import qiskit
import flask

print("✅ Basic libraries work!")
print("✅ ML libraries work!")
print("✅ SHAP works!")
print(f"   SHAP version: {shap.__version__}")
print("✅ Qiskit works!")
print(f"   Qiskit version: {qiskit.__version__}")
print("✅ Flask works!")
print("\n🎉 All libraries installed successfully!")
# Out:
# ✅ Basic libraries work!
# ✅ ML libraries work!
# ✅ SHAP works!
#    SHAP version: 0.41.0
# ✅ Qiskit works!
#    Qiskit version: 2.3.0
# ✅ Flask works!
#
# 🎉 All libraries installed successfully!

# %%
import pandas as pd
import requests
from io import StringIO
import time

print("🔬 Starting ClinVar BRCA Data Download...")
print("=" * 60)

# ClinVar FTP download URL for variant summary
# This contains all ClinVar variants with their classifications
url = "https://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/variant_summary.txt.gz"

print(f"\n📡 Downloading data from ClinVar...")
print(f"URL: {url}")
print("⏳ This may take 2-5 minutes (file is ~500MB)...\n")

try:
    # Download the data
    df = pd.read_csv(url, sep='\t', compression='gzip', low_memory=False)
    
    print(f"✅ Download complete!")
    print(f"📊 Total variants downloaded: {len(df):,}")
    
    # Filter for BRCA1 and BRCA2 genes only
    print("\n🧬 Filtering for BRCA1 and BRCA2 genes...")
    brca_df = df[df['GeneSymbol'].isin(['BRCA1', 'BRCA2'])].copy()
    print(f"✅ BRCA variants found: {len(brca_df):,}")
    
    # Filter for clear classifications (Benign or Pathogenic)
    print("\n🎯 Filtering for clear classifications...")
    
    # Keep only variants with clear benign or pathogenic classifications
    benign_terms = ['Benign', 'Likely benign']
    pathogenic_terms = ['Pathogenic', 'Likely pathogenic']
    
    brca_df = brca_df[
        brca_df['ClinicalSignificance'].isin(benign_terms + pathogenic_terms)
    ].copy()
    
    print(f"✅ Variants with clear classifications: {len(brca_df):,}")
    
    # Create binary label (0 = Benign, 1 = Pathogenic)
    brca_df['Label'] = brca_df['ClinicalSignificance'].apply(
        lambda x: 0 if x in benign_terms else 1
    )
    
    # Select relevant columns
    columns_to_keep = [
        'GeneSymbol',
        'ClinicalSignificance', 
        'Type',
        'Name',
        'Assembly',
        'Chromosome',
        'Start',
        'Stop',
        'ReviewStatus',
        'Label'
    ]
    
    brca_clean = brca_df[columns_to_keep].copy()
    
    # Display summary statistics
    print("\n" + "=" * 60)
    print("📊 DATASET SUMMARY")
    print("=" * 60)
    print(f"\nTotal BRCA mutations: {len(brca_clean):,}")
    print(f"\nBreakdown by gene:")
    print(brca_clean['GeneSymbol'].value_counts())
    print(f"\nBreakdown by classification:")
    print(brca_clean['ClinicalSignificance'].value_counts())
    print(f"\nBreakdown by type:")
    print(brca_clean['Type'].value_counts().head(10))
    
    # Save to CSV
    output_file = 'brca_mutations.csv'
    brca_clean.to_csv(output_file, index=False)
    print(f"\n💾 Data saved to: {output_file}")
    
    # Display first few rows
    print("\n" + "=" * 60)
    print("👀 FIRST 5 ROWS OF DATA:")
    print("=" * 60)
    print(brca_clean.head())
    
    print("\n✅ SUCCESS! Data is ready for analysis!")
    print(f"📁 File location: {output_file}")
    
except Exception as e:
    print(f"\n❌ Error occurred: {e}")
    print("\n💡 If download fails
# Out:
#   Cell In[1], line 91
#     print("\n💡 If download fails
#           ^
# SyntaxError: unterminated string literal (detected at line 91)
